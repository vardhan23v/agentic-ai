# %% [markdown]
# <a href="https://colab.research.google.com/github/vardhan23v/agentic-ai/blob/main/text_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the OpenAI Python library
# !pip install pillow requests --quiet openai

# %%
from google.colab import userdata
api_key=userdata.get('api_key')

# %%
from openai import OpenAI
import base64
from PIL import Image
from IPython.display import display

client = OpenAI(
    api_key=api_key,
    base_url="https://nexusapi.navigatelabs.ai"
)

# Generate image
result = client.images.generate(
    model="nano-banana",
    prompt="A liger "
)

# Decode the base64 image
image_base64 = result.data[0].b64_json
image_bytes = base64.b64decode(image_base64)

# Save the image
image_path = "canva.png"
with open(image_path, "wb") as f:
    f.write(image_bytes)

print(f"Image saved as {image_path}")

# Display the image in Colab
try:
    img = Image.open(image_path)
    display(img)
except FileNotFoundError:
    print(f"{image_path} not found. Please make sure the image generation was successful.")
# Out:
# Image saved as canva.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
