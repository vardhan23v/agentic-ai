# %% [markdown]
# <a href="https://colab.research.google.com/github/vardhan23v/agentic-ai/blob/main/text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai -q

# %%
from google.colab import userdata
api_key=userdata.get('api_key')

# %%
from openai import OpenAI
from IPython.display import Audio, display


client = OpenAI(
    api_key=api_key,
    base_url="https://nexusapi.navigatelabs.ai"
)

response = client.audio.speech.create(
    model="gpt-4o-mini-tts",
    voice="alloy",
    input="Hi. This is Navi from Navigate Labs.",
    response_format="mp3"
)

display(Audio(response.content, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
